# %%
import numpy as np
import pandas as pd
import requests, re, zipfile, logging, sys
from datetime import datetime
from pathlib import Path

import folium
from IPython.display import display

# %%
traffic_images_url = "https://datamall2.mytransport.sg/ltaodataservice/Traffic-Imagesv2"
api_key = "AO4qMbK3S7CWKSlplQZqlA=="

headers = {
    'AccountKey' : api_key
}

# %%
# Load the camera info CSV file
df = pd.read_csv('camera_info.csv')

# Initialize a map centered on Singapore
singapore_map = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

# Iterate over the rows of the DataFrame and add points to the map
for index, row in df.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']
    camera_id = int(row['CameraID'])
    
    # Add a marker with a popup showing the camera ID and a tooltip for mouseover
    folium.Marker(
        location=[lat, lon],
        popup=f'Camera ID: {camera_id}',
        tooltip=camera_id  # Show the camera ID on hover
    ).add_to(singapore_map)

# Display the map in the notebook
display(singapore_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d6da0d7c82957585e1824b3609f97ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d6da0d7c82957585e1824b3609f97ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d6da0d7c82957585e1824b3609f97ea = L.map(
#                 &quot;map_6d6da0d7c82957585e1824b3609f97ea&quot;,
#                 {
#                     center: [1.3521, 103.8198],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_011b9c7ae70941ce7397c3b021037422 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_011b9c7ae70941ce7397c3b021037422.addTo(map_6d6da0d7c82957585e1824b3609f97ea);
#
#
#             var marker_92310b5228a8509908c59256f5e1409e = L.marker(
#                 [1.29531332, 103.871146],
#                 {
# }
#             ).addTo(map_6d6da0d7c82957585e1824b3609f97ea);
#
#
#         var popup_b606cf15ff4e20e7c5a351250594a01e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc96a5e2ca8b8916b247b9a21646c62f = $(`&lt;div id=&quot;html_cc96a5e2ca8b8916b247b9a21646c62f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Camera ID: 1001&lt;/div&gt;`)[0];
#                 popup_b606cf15ff4e20e7c5a351250594a01e.setContent(html_cc96a5e2ca8b8916b247b9a21646c62f);
#
#
#
#         marker_92310b5228a8509908c59256f5e1409e.bindPopup(popup_b606cf15ff4e20e7c5a351250594a01e)
#         ;
#
#
#
#
#             marker_92310b5228a8509908c59256f5e1409e.bindTooltip(
#                 `&lt;div&gt;
#                      1001
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_23310b8da8c85a58e4438f10c8e019c5 = L.marker(
#                 [1.319541067, 103.8785627],
#                 {
# }
#             ).addTo(map_6d6da0d7c82957585e1824b3609f97ea);
#
#
#         var popup_bd56e0994218fd07c7b3c937b93754df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ed2048590c67bbcc81a937be6475546 = $(`&lt;div id=&quot;html_2ed2048590c67bbcc81a937be6475546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Camera ID: 1002&lt;/div&gt;`)[0];
#                 popup_bd56e0994218fd07c7b3c937b93754df.setContent(html_2ed2048590c67bbcc81a937be6475546);
#
#
#
#         marker_23310b8da8c85a58e4438f10c8e019c5.bindPopup(popup_bd56e0994218fd07c7b3c937b93754df)
#         ;
#
#
#
#
#             marker_23310b8da8c85a58e4438f10c8e019c5.bindTooltip(
#                 `&lt;div&gt;
#                      1002
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_e73ebc38fc83f1242b43064b5ca8d6ba = L.marker(
#                 [1.323957439, 103.8728576],
#                 {
# }
#             ).addTo(map_6d6da0d7c82957585e1824b3609f97ea);
#
#
#         var popup_a9cd7e4af5b7cdc0a1cc345edd125f87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3faf9e5091ede1e4a2fcbf650587c3ac = $(`&lt;div id=&quot;html_3faf9e5091ede1e4a2fcbf650587c3ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Camera ID: 1003&lt;/div&gt;`)[0];
#                 popup_a9cd7e4af5b7cdc0a1cc345edd125f87.setContent(html_3faf9e5091ede1e4a2fcbf650587c3ac);
#
#
#
#         marker_e73ebc38fc83f1242b43064b5ca8d6ba.bindPopup(popup_a9cd7e4af5b7cdc0a1cc345edd125f87)
#         ;
#
#
#
#
#             marker_e73ebc38fc83f1242b43064b5ca8d6ba.bindTooltip(
#                 `&lt;div&gt;
#                      1003
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7f43e77ae835b134a24f771add2038fd = L.marker(
#                 [1.319535712, 103.8750668],
#                 {
# }
#             ).addTo(map_6d6da0d7c82957585e1824b3609f97ea);
#
#
#         var popup_768af7bbc1be978160d0b94e159ee27a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4e7166dbf7fbd32a9a7f70a4466650c = $(`&lt;div id=&quot;html_d4e7166dbf7fbd32a9a7f70a4466650c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Camera ID: 1004&lt;/div&gt;`)[0];
#                 popup_768af7bbc1be978160d0b94e159ee27a.setContent(html_d4e7166dbf7fbd32a9a7f70a4466650c);
#
#
#
#         marker_7f43e77ae835b134a24f771add2038fd.bindPopup(popup_768af7bbc1be978160d0b94e159ee27a)
#         ;

# %%
outzipfile = "lta_images.zip"

try:
    r3 = requests.get(traffic_images_url, headers=headers)

    # retrieve images
    for ii in r3.json()['value']:
        img_link = ii['ImageLink'] 
        xx = re.search('.*(?<=.jpg)', img_link) 
        fname = re.split('/', xx.group())[-1]
        r4 = requests.get(img_link, headers=headers)
        
        with open(fname, 'wb') as f:
            f.write(r4.content)
            print(f'{fname} written..')
      
        with zipfile.ZipFile(outzipfile, 'a', zipfile.ZIP_DEFLATED) as ff:
            ff.write(fname)
            print(f'{fname} written to zip..')

        Path(fname).unlink()
    
except Exception as err: 
    print(f"Error {err} occurred.")
# Out:
# 1001_2303_20250826150543_EF0333.jpg written..
# 1001_2303_20250826150543_EF0333.jpg written to zip..
# 1002_2303_20250826150546_468F0F.jpg written..
# 1002_2303_20250826150546_468F0F.jpg written to zip..
# 1003_2303_20250826150547_F6DB63.jpg written..
# 1003_2303_20250826150547_F6DB63.jpg written to zip..
# 1004_2303_20250826150546_3A1F9D.jpg written..
# 1004_2303_20250826150546_3A1F9D.jpg written to zip..
# 1005_2303_20250826150546_7CABE3.jpg written..
# 1005_2303_20250826150546_7CABE3.jpg written to zip..
# 1006_2303_20250826150545_2C9C86.jpg written..
# 1006_2303_20250826150545_2C9C86.jpg written to zip..
# 1111_2255_20250826150550_B2A805.jpg written..
# 1111_2255_20250826150550_B2A805.jpg written to zip..
# 1112_2255_20250826150549_4021BD.jpg written..
# 1112_2255_20250826150549_4021BD.jpg written to zip..
